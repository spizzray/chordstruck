# %%
import autochord
# Out:
# autochord: Initializing...
# autochord: Using NNLS-Chroma VAMP plugin in /Users/oudea/Library/Audio/Plug-Ins/Vamp
# autochord: Loaded model from /Users/oudea/.autochord/chroma-seq-bilstm-crf-v1

# %%
Data = autochord.recognize('Perfect.wav', lab_fn='chords.lab')
Data
# Out:
# 1/1 [==============================] - 1s 1s/step
# [(0.0, 7.476825396825397, 'Ab:maj'),
#  (7.476825396825397, 11.42421768707483, 'F:min'),
#  (11.42421768707483, 15.232290249433106, 'Db:maj'),
#  (15.232290249433106, 18.854603174603174, 'Eb:maj'),
#  (18.854603174603174, 22.6162358276644, 'Ab:maj'),
#  (22.6162358276644, 26.656507936507936, 'F:min'),
#  (26.656507936507936, 29.72154195011338, 'Db:maj'),
#  (29.72154195011338, 30.696780045351474, 'N'),
#  (30.696780045351474, 33.94757369614513, 'Eb:maj'),
#  (33.94757369614513, 37.8485260770975, 'Ab:maj'),
#  (37.8485260770975, 41.61015873015873, 'F:min'),
#  (41.61015873015873, 45.55755102040816, 'Db:maj'),
#  (45.55755102040816, 47.55446712018141, 'Ab:maj'),
#  (47.55446712018141, 49.13342403628118, 'Eb:maj'),
#  (49.13342403628118, 53.080816326530616, 'Ab:maj'),
#  (53.080816326530616, 56.70312925170068, 'F:min'),
#  (56.70312925170068, 60.46476190476191, 'Db:maj'),
#  (60.46476190476191, 61.11492063492064, 'Eb:min'),
# ...

# %%
Data = str(Data)

# %%
print(Data.replace('(', '[').replace('),','],\n'))
# Out:
# [[0.0, 7.476825396825397, 'Ab:maj'],
#  [7.476825396825397, 11.42421768707483, 'F:min'],
#  [11.42421768707483, 15.232290249433106, 'Db:maj'],
#  [15.232290249433106, 18.854603174603174, 'Eb:maj'],
#  [18.854603174603174, 22.6162358276644, 'Ab:maj'],
#  [22.6162358276644, 26.656507936507936, 'F:min'],
#  [26.656507936507936, 29.72154195011338, 'Db:maj'],
#  [29.72154195011338, 30.696780045351474, 'N'],
#  [30.696780045351474, 33.94757369614513, 'Eb:maj'],
#  [33.94757369614513, 37.8485260770975, 'Ab:maj'],
#  [37.8485260770975, 41.61015873015873, 'F:min'],
#  [41.61015873015873, 45.55755102040816, 'Db:maj'],
#  [45.55755102040816, 47.55446712018141, 'Ab:maj'],
#  [47.55446712018141, 49.13342403628118, 'Eb:maj'],
#  [49.13342403628118, 53.080816326530616, 'Ab:maj'],
#  [53.080816326530616, 56.70312925170068, 'F:min'],
#  [56.70312925170068, 60.46476190476191, 'Db:maj'],
#  [60.46476190476191, 61.11492063492064, 'Eb:min'],
#  [61.11492063492064, 63.25115646258504, 'Eb:maj'],
# ...
